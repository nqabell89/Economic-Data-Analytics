# %%
# Import libraries
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# Out:
# C:\Users\nqabe\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Authenticate quandl api key
quandl_api_key = "Zmns8n4ypL4kRmFxnsxC"
quandl.ApiConfig.api_key = quandl_api_key

# %%
df = quandl.get('LBMA/GOLD') # London Gold Bullion Spot Price
df.rename(columns = {'Value':'Gold_Price_USD'}, inplace = True)

df = pd.merge(df, quandl.get('MULTPL/SHILLER_PE_RATIO_MONTH'), left_index = True, right_index = True)
df.rename(columns = {'Value':'Shiller_SP500_PE_Ratio'}, inplace = True)

df = pd.merge(df, quandl.get('MULTPL/SP500_INFLADJ_MONTH'), left_index = True, right_index = True)
df.rename(columns = {'Value':'SP500_INFL_ADJ'}, inplace = True)

# %%
df = df[['USD (AM)', 'Shiller_SP500_PE_Ratio', 'SP500_INFL_ADJ']]
df
# Out:
#             USD (AM)  Shiller_SP500_PE_Ratio  SP500_INFL_ADJ
# Date
# 1968-02-01     35.20                   20.42          684.07
# 1968-03-01     35.20                   19.93          669.60
# 1968-04-01     38.00                   21.28          716.96
# 1968-05-01     39.10                   21.63          731.32
# 1968-07-01     40.90                   21.75          740.89
# ...              ...                     ...             ...
# 2020-05-01   1673.05                   27.34         2935.59
# 2020-06-01   1734.80                   28.84         3104.66
# 2020-06-30   1770.70                   29.07         3100.29
# 2020-07-01   1787.40                   29.73         3207.62
# 2020-07-31   1974.70                   30.49         3271.12
#
# [407 rows x 3 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
df.groupby(pd.Grouper(freq='Y', closed='right')).head()
# Out:
#             USD (AM)  Shiller_SP500_PE_Ratio  SP500_INFL_ADJ
# Date
# 1968-02-01     35.20                   20.42          684.07
# 1968-03-01     35.20                   19.93          669.60
# 1968-04-01     38.00                   21.28          716.96
# 1968-05-01     39.10                   21.63          731.32
# 1968-07-01     40.90                   21.75          740.89
# ...              ...                     ...             ...
# 2020-01-31   1580.85                   30.84         3225.04
# 2020-02-28   1626.35                   28.05         2954.81
# 2020-03-31   1604.65                   24.40         2584.59
# 2020-04-01   1594.25                   25.93         2777.14
# 2020-04-30   1716.75                   27.27         2912.43
#
# [265 rows x 3 columns]

# %%
#World Bank Data - US
wb_us = pd.read_csv('data/US Annual WB Data - API_USA_DS2_en_csv_v2_1221790.csv')

# %%
wb_us
# Out:
#                                          Indicator Name        Indicator Code  \
# 0     Internally displaced persons, total displaced ...           VC.IDP.TOCV
# 1     Merchandise exports to low- and middle-income ...     TX.VAL.MRCH.R4.ZS
# 2                      Export volume index (2000 = 100)     TX.QTY.MRCH.XD.WD
# 3     Merchandise imports from low- and middle-incom...     TM.VAL.MRCH.R1.ZS
# 4     Tariff rate, most favored nation, simple mean,...  TM.TAX.TCOM.SM.FN.ZS
# ...                                                 ...                   ...
# 1372   Portfolio equity, net inflows (BoP, current US$)     BX.PEF.TOTL.CD.WD
# 1373  Grants, excluding technical cooperation (BoP, ...     BX.GRT.EXTA.CD.WD
# 1374  Foreign direct investment, net outflows (BoP, ...     BM.KLT.DINV.CD.WD
# 1375            Crop production index (2004-2006 = 100)        AG.PRD.CROP.XD
# 1376            Land under cereal production (hectares)        AG.LND.CREL.HA
#
# ...
